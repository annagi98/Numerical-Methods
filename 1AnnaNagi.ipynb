# %%
 #Anna Nagi
from math import sqrt, pi, sin
 
#zad 1
k = 1240 * sqrt(7)     #float
m = 4467               #int
l = 2j                 #complex
d = k + m              #float = float + int
c = d + l              #complex = float + complex

# %%
#zad 2
print(d)               #domyslnie
print("%.3f" % d)      #trzy po przecinku
print("%.20f" % d)     #dwadziescia po przecinku
# Out:
# 7747.731625720093
# 7747.732
# 7747.73162572009277937468

# %%
#zad 3
r = 17                 #promien
h = 33                 #wysokosc
pp = pi * r**2          #pole podstawy
pb = 2 * pi * r * h    #pole boczne
S = 2 * pp + pb        #pole powierzchni walca
print('Pole powierzchni walca wynosi: ', S)
# Out:
# Pole powierzchni walca wynosi:  5340.707511102648

# %%
#zad 4
"""
komentarz
"""
# Out:
# '\nkomentarz\n'

# %%
#zad 5
#przykladowe liczby:
x1=1
t=2
r=3

B=((x1 + r) * (x1 **(t*r))) / (r * sin(2 * x1) + 3.3456)
print(B)
# Out:
# 0.6585996680785801

# %%
#zad 6
from math import sqrt
from numpy import array
from numpy.linalg import inv, det

a = sqrt(2)
M = array([ [a, 1, -a],     #macierz M
            [0, 1, 1],
            [-a, a, 1]])

print("\nMacierz normalna:")
print("{0}".format(M))

macierz_odwrotna = inv(M)
print("\nMacierz odwrotna:")
print("{0}".format(macierz_odwrotna))

macierz_transponowana = M.transpose()
print("\nMacierz transponowana:")
print("{0}".format(macierz_transponowana))

wyznacznik_M = det(M)
print("\nWyznacznik macierzy M = ", wyznacznik_M)



#zad 7 - wypisywanie elementów macierzy M

print("M(1,1) = ", M[0, 0])
print("M(3,3) = ", M[2, 2])
print("M(3,2) = ", M[2, 1])


w1 = M[:, 2]                                #wektor w1
print("\n\nWektor w1: \n {0}".format(w1))

w2 = M[1, :]                                #wektor w2
print("\nWektor w2: \n {0}".format(w2))
# Out:
# Macierz normalna:
# [[ 1.41421356  1.         -1.41421356]
#  [ 0.          1.          1.        ]
#  [-1.41421356  1.41421356  1.        ]]
#
# Macierz odwrotna:
# [[ 0.10355339  0.75       -0.60355339]
#  [ 0.35355339  0.14644661  0.35355339]
#  [-0.35355339  0.85355339 -0.35355339]]
#
# Macierz transponowana:
# [[ 1.41421356  0.         -1.41421356]
#  [ 1.          1.          1.41421356]
#  [-1.41421356  1.          1.        ]]
#
# Wyznacznik macierzy M =  -4.0
# M(1,1) =  1.41421356237
# M(3,3) =  1.0
# M(3,2) =  1.41421356237
#
#
# Wektor w1:
#  [-1.41421356  1.          1.        ]
#
# Wektor w2:
#  [ 0.  1.  1.]

# %%
from numpy import roots

#zad 8

wspolczynniki = [1, -7, 3, 43, -28, -60]
print("Pierwiastki wielomianu obliczone numerycznie:", end="")
print(roots(wspolczynniki))

print("\n\nJesli wyswietli sie 5 razy liczba zero, to pierwiastki sa poprawne\n")


pierwiastki = [5, 3, 2, -2, -1]

for x in pierwiastki:
    wx = x**5 - 7*x**4 + 3*x**3 + 43*x**2 - 28*x - 60
    print(wx, end="")
# Out:
# Pierwiastki wielomianu obliczone numerycznie:[ 5.  3.  2. -2. -1.]
#
#
# Jesli wyswietli sie 5 razy liczba zero, to pierwiastki sa poprawne
#
# 00000

# %%
#zad 9

from numpy import arange, linspace

#podajemy poczatek, koniec i krok
#- komputer sam wylicza ilosc licb w ciagu
#w arange liczba koncowa nie nalezy do przedzialu liczb w ciagu,
#a w linspace nalezy
ciag1 = arange(1, 19, 1.5)    
print("\nCiag 1 (arange): ", ciag1)

#podajemy poczatek, koniec i ilosc liczb pomiedzy nimi
#- komputer sam oblicza krok
ciag2 = linspace(1, 19, 13)   
print("\nCiag 2 (linspace): ", ciag2)
# Out:
# Ciag 1 (arange):  [  1.    2.5   4.    5.5   7.    8.5  10.   11.5  13.   14.5  16.   17.5]
#
# Ciag 2 (linspace):  [  1.    2.5   4.    5.5   7.    8.5  10.   11.5  13.   14.5  16.   17.5
#   19. ]

# %%
#zad 10
from numpy import linspace
import matplotlib.pyplot as plt

def funkcja1(x):
    return x**3 - 3*x

#wykres 1.
x = linspace(-1, 1)
y = [funkcja1(i) for i in x]

plt.plot(x, y)
plt.title('Wykres dla x nalezacego do przedzialu od -1 do 1: ')
plt.xlabel('x')
plt.ylabel('y')
plt.legend('Wykres 1.')
plt.show()


#wykres 2.
x = linspace(-5, 5)
y = [funkcja1(i) for i in x]

plt.plot(x, y)
plt.title('Wykres dla x nalezacego do przedzialu od -5 do 5: ')
plt.xlabel('x')
plt.ylabel('y')
plt.legend('Wykres 2.')
plt.show()


#wykres 3.
x = linspace(0, 5)
y = [funkcja1(i) for i in x]

plt.plot(x, y)
plt.title('Wykres dla x nalezacego do przedzialu od 0 do 5: ')
plt.xlabel('x')
plt.ylabel('y')
plt.legend('Wykres 3.')
plt.show()

# %%
#zad 10
from numpy import linspace
import matplotlib.pyplot as plt
from matplotlib.pyplot import semilogy


def cieplo(m_g, v_km_h):
    m_kg = m_g / 1000

    v_m_h = v_km_h * 1000
    v_m_s = v_m_h / 3600

    return (m_kg * v_m_s**2) / 2


wynik = cieplo(2500, 60)
print("\nWynik w dżulach: ", wynik)

q_kcal = wynik * 4186.8
print("\nWynik w kilokaloriach: ", q_kcal)


v_km_h = linspace(200, 0)

y = [cieplo(3000, i) for i in v_km_h]

plt.plot(v_km_h, y)
plt.title('Zaleznosc liniowa ilosci ciepla wydzielonego podczas hamowania od predkosci dla ciala o masie 3000g: ')
plt.xlabel('predkosc')
plt.ylabel('ilosc ciepla')
plt.legend('Wykres 1. (skala liniowa) ')
plt.show()


semilogy(v_km_h, y)
plt.title('Zaleznosc logarytmiczna ilosci ciepla wydzielonego podczas hamowania od predkosci dla ciala o masie 3000g: ')
plt.xlabel('predkosc')
plt.ylabel('ilosc ciepla')
plt.legend('Wykres 2. (skala logarytmiczna) ')
plt.show()
# Out:
# Wynik w dżulach:  347.2222222222223
#
# Wynik w kilokaloriach:  1453750.0000000002
